# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv("sonar_data.csv", header = None)
dataset
# Out:
#          0       1       2       3       4       5       6       7       8   \
# 0    0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1    0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2    0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3    0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4    0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 203  0.0187  0.0346  0.0168  0.0177  0.0393  0.1630  0.2028  0.1694  0.2328
# 204  0.0323  0.0101  0.0298  0.0564  0.0760  0.0958  0.0990  0.1018  0.1030
# 205  0.0522  0.0437  0.0180  0.0292  0.0351  0.1171  0.1257  0.1178  0.1258
# 206  0.0303  0.0353  0.0490  0.0608  0.0167  0.1354  0.1465  0.1123  0.1945
# 207  0.0260  0.0363  0.0136  0.0272  0.0214  0.0338  0.0655  0.1400  0.1843
#
# ...

# %%
dataset.isnull().sum()
# Out:
# 0     0
# 1     0
# 2     0
# 3     0
# 4     0
#      ..
# 56    0
# 57    0
# 58    0
# 59    0
# 60    0
# Length: 61, dtype: int64

# %% [markdown]
# All the observations have 60 attributes in the range 0.0 to 1.0. Each number represents the energy within a particular frequency band, integrated over a certain period of time. The integration aperture for higher frequencies occur later in time, since these frequencies are transmitted later during the chirp.

# %%
import seaborn as sn

plt.rcParams["figure.figsize"] = (70, 35)
mask = np.triu(np.ones_like(dataset.corr()))
sn.heatmap(dataset.corr(),cmap="YlGnBu", annot=True, mask = mask)

plt.title("Correlation of every column with each other")
# Out:
# Text(0.5, 1.0, 'Correlation of every column with each other')

# %%
dataset.describe()
# Out:
#                0           1           2           3           4           5   \
# count  208.000000  208.000000  208.000000  208.000000  208.000000  208.000000
# mean     0.029164    0.038437    0.043832    0.053892    0.075202    0.104570
# std      0.022991    0.032960    0.038428    0.046528    0.055552    0.059105
# min      0.001500    0.000600    0.001500    0.005800    0.006700    0.010200
# 25%      0.013350    0.016450    0.018950    0.024375    0.038050    0.067025
# 50%      0.022800    0.030800    0.034300    0.044050    0.062500    0.092150
# 75%      0.035550    0.047950    0.057950    0.064500    0.100275    0.134125
# max      0.137100    0.233900    0.305900    0.426400    0.401000    0.382300
#
#                6           7           8           9   ...          50  \
# count  208.000000  208.000000  208.000000  208.000000  ...  208.000000
# mean     0.121747    0.134799    0.178003    0.208259  ...    0.016069
# ...

# %%
x = dataset.iloc[:,:-1]
y = dataset.iloc[:,-1]
len(x) == len(y)
# Out:
# True

# %%
y.value_counts()
# Out:
# M    111
# R     97
# Name: 60, dtype: int64

# %% [markdown]
# The dataset is almost balanced so we dont need to change the number of observations in the dataset.
#
# As we have only 2 output R(Rock) or M(Mines) we can encode them as follows:

# %%
y_values = {"M":1,"R":0}

# %%
y_converted = y.apply(lambda value: y_values[value])
y_converted
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 203    1
# 204    1
# 205    1
# 206    1
# 207    1
# Name: 60, Length: 208, dtype: int64

# %% [markdown]
# Splitting the dataset into Training and Testing sets

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB, BernoulliNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import ShuffleSplit

def find_best_model_using_gridsearchcv(X,y):
    algos = {
        'logistic_regression' : {
            'model': LogisticRegression(),
            'params': {
            }
        },
        'K neighbour' :{
            'model' : KNeighborsClassifier(),
            'params':{
            }
        },
        'Support Vector Machine':{
            'model':SVC(),
            'params':{
            }
        },
        'Bernoulli':{
            'model':BernoulliNB(),
            'params':{}
        },
        'Gaussian':{
            'model':GaussianNB(),
            'params':{}
        },
        'Decision Tree':{
            'model':DecisionTreeClassifier(),
            'params':{
            }
        }
        
    }
    scores = []
    cv = ShuffleSplit(n_splits=5, test_size=0.2, random_state=0)
    for algo_name, config in algos.items():
        print(algo_name)
        gs =  GridSearchCV(config['model'], config['params'], cv=cv, return_train_score=False)
        gs.fit(X,y)
        scores.append({
            'model': algo_name,
            'best_score': gs.best_score_,
            'best_params': gs.best_params_
        })

    return pd.DataFrame(scores,columns=['model','best_score','best_params'])

find_best_model_using_gridsearchcv(x,y)
# Out:
# logistic_regression
# K neighbour
# Support Vector Machine
# Bernoulli
# Gaussian
# Decision Tree
#                     model  best_score best_params
# 0     logistic_regression    0.809524          {}
# 1             K neighbour    0.780952          {}
# 2  Support Vector Machine    0.809524          {}
# 3               Bernoulli    0.571429          {}
# 4                Gaussian    0.657143          {}
# 5           Decision Tree    0.666667          {}

# %%
def find_best_model_using_gridsearchcv(X,y):
    algos = {
        'logistic_regression' : {
            'model': LogisticRegression(),
            'params': {
                'penalty':['l1', 'l2',None],
                'multi_class' : ['auto','ovr','multinomial']
            }
        },
        'Support Vector Machine':{
            'model':SVC(),
            'params':{
                'kernel':['linear','poly','rbf'],
                'gamma':['auto','scale'],
                'class_weight' :['balanced',None],
                'decision_function_shape':['ovo','ovr']
            }
        }
    }
    scores = []
    cv = ShuffleSplit(n_splits=5, test_size=0.2, random_state=0)
    for algo_name, config in algos.items():
        print(algo_name)
        gs =  GridSearchCV(config['model'], config['params'], cv=cv, return_train_score=False)
        gs.fit(X,y)
        scores.append({
            'model': algo_name,
            'best_score': gs.best_score_,
            'best_params': gs.best_params_
        })

    return pd.DataFrame(scores,columns=['model','best_score','best_params'])

find_best_model_using_gridsearchcv(x,y)
# Out:
# logistic_regression
# /Users/vivekgoel/miniforge3/envs/jarvis2.0/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:372: FitFailedWarning:
# 30 fits failed out of a total of 45.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 15 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/vivekgoel/miniforge3/envs/jarvis2.0/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/vivekgoel/miniforge3/envs/jarvis2.0/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py", line 1461, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
# ...

# %%
#{'class_weight': 'balanced', 'decision_function_shape': 'ovo', 'gamma': 'scale', 'kernel': 'poly'}
model = SVC(class_weight ='balanced', decision_function_shape = 'ovo', gamma = 'scale', kernel = 'poly')
model.fit(x_train,y_train)
# Out:
# SVC(class_weight='balanced', decision_function_shape='ovo', kernel='poly')

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, model.predict(x_test))
import seaborn as sn
plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(69.0, 0.5, 'Truth')

# %%
import joblib 
joblib.dump(model, 'sonar_rock_vs_mines_detection.pkl')
# Out:
# ['sonar_rock_vs_mines_detection.pkl']

# %%
from sklearn.metrics import classification_report
target_names = ['Mines', 'Rock']
print(classification_report(y_test, model.predict(x_test), target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#        Mines       0.78      0.86      0.82        21
#         Rock       0.84      0.76      0.80        21
#
#     accuracy                           0.81        42
#    macro avg       0.81      0.81      0.81        42
# weighted avg       0.81      0.81      0.81        42
